# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().system('mkdir -p ~/.kaggle')
#       2 get_ipython().system('cp kaggle.json ~/.kaggle/')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\zmqshell.py:647, in ZMQInteractiveShell.system_piped(self, cmd)
#     645         if path is not None:
#     646             cmd = f"pushd {path} &&{cmd}"
# --> 647         self.user_ns["_exit_code"] = system(cmd)
#     648 else:
#     649     self.user_ns["_exit_code"] = system(self.var_expand(cmd, depth=1))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\utils\_process_win32.py:124, in system(cmd)
#     122 if path is not None:
#     123     cmd = '"pushd %s &&"%s' % (path, cmd)
# --> 124 return process_handler(cmd, _system_body)
#
# ...

# %%
# !kaggle datasets download -d salader/dogs-vs-cats
